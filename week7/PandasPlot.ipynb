# %% [markdown]
# <a href="https://colab.research.google.com/github/macgyver121/DADS5001/blob/main/week7/PandasPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reference: https://pandas.pydata.org/docs/user_guide/visualization.html

# %%
#import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Line chart

# %%
ts = pd.Series(np.random.randn(100), index=pd.date_range("1/1/2000", periods=100))
ts.plot();

# %%
ts = ts.cumsum()
ts.plot();

# %%
df = pd.DataFrame(np.random.randn(100, 4), index=ts.index, columns=list("ABCD"))

df = df.cumsum()

#plt.figure();

df.plot();

# %% [markdown]
# ## 2. Bar plot

# %%
#plt.figure();

df.iloc[0].plot(kind="bar");

# %% [markdown]
# Multiple bar plot

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

df2.plot.bar();

# %%
df2.plot.bar(stacked=True);

# %%
df2.plot.barh(stacked=True);

# %% [markdown]
# ## 3. Histogram

# %% [markdown]
# randn generates samples from the normal distribution, while numpy. random. rand from a uniform distribution (in the range [0,1))

# %%
df4 = pd.DataFrame(
    {
        "a": np.random.randn(1000) + 1,
        "b": np.random.randn(1000),
        "c": np.random.randn(1000) - 1,
    },
    columns=["a", "b", "c"],
)


#plt.figure();

df4.plot.hist(alpha=0.5);

# %% [markdown]
# ## 4. Box plots

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])

df.plot.box();

# %%
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8])

# %% [markdown]
# ## 5. Area plot

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

df.plot.area();

# %% [markdown]
# ## 6. Scatter plot

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])

df["species"] = pd.Categorical(
    ["setosa"] * 20 + ["versicolor"] * 20 + ["virginica"] * 10
)

df.plot.scatter(x="a", y="b");

# %%
ax = df.plot.scatter(x="a", y="b", color="DarkBlue", label="Group 1")

df.plot.scatter(x="c", y="d", color="DarkGreen", label="Group 2", ax=ax);

# %%
df.plot.scatter(x="a", y="b", c="c", s=50);

# %%
df.plot.scatter(x="a", y="b", c="species", cmap="viridis", s=50);

# %%
df.plot.scatter(x="a", y="b", s=df["c"] * 200);

# %% [markdown]
# ## 7. Pie chart

# %%
series = pd.Series(3 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")
series.plot.pie(figsize=(6, 6));

# %%
df = pd.DataFrame(
    3 * np.random.rand(4, 2), index=["a", "b", "c", "d"], columns=["x", "y"]
)

df.plot.pie(subplots=True, figsize=(8, 4));

# %%
series.plot.pie(
    labels=["AA", "BB", "CC", "DD"],
    colors=["r", "g", "b", "c"],
    autopct="%.1f",
    fontsize=20,
    figsize=(6, 6),
);

# %% [markdown]
# # Plotting tools
# ## 8. Scatter matrix plot

# %%
from pandas.plotting import scatter_matrix

df = pd.DataFrame(np.random.randn(1000, 4), columns=["a", "b", "c", "d"])

scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal="kde");

# %% [markdown]
# ### Density plot

# %%
ser = pd.Series(np.random.randn(1000))

ser.plot.kde();

# %%
from pandas.plotting import radviz

data = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/pandas/tests/io/data/csv/iris.csv")

#plt.figure();

radviz(data, "Name");
